# %%
# accessing icloud
# install the package
# !pip install pyicloud
# Out:
# Collecting pyicloud
#   Downloading https://files.pythonhosted.org/packages/5c/5b/4d1fd61abc9f17cfb9ff0ce05c67f7b91ba2072f8fb7e6042316b5e539ec/pyicloud-0.9.7-py3-none-any.whl
# Collecting six>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/ee/ff/48bde5c0f013094d729fe4b0316ba2a24774b3ff1c52d924a8a4cb04078a/six-1.15.0-py2.py3-none-any.whl
# Collecting keyring<=9.3.1,>=8.0
#   Downloading https://files.pythonhosted.org/packages/45/7b/de9c4c0217529d8099e27c935364b84437fd24f1354e8c0151395d28e3ae/keyring-9.3.1-py2.py3-none-any.whl
# Collecting click<=7.1.1,>=6.0
#   Downloading https://files.pythonhosted.org/packages/dd/c0/4d8f43a9b16e289f36478422031b8a63b54b6ac3b1ba605d602f10dd54d6/click-7.1.1-py2.py3-none-any.whl (82kB)
#      |████████████████████████████████| 92kB 6.7MB/s
# Collecting future>=0.18.2
#   Downloading https://files.pythonhosted.org/packages/45/0b/38b06fd9b92dc2b68d58b75f900e97884c45bedd2ff83203d933cf5851c9/future-0.18.2.tar.gz (829kB)
#      |████████████████████████████████| 829kB 17.0MB/s
# Collecting keyrings.alt<=3.2.0,>=1.0
#   Downloading https://files.pythonhosted.org/packages/80/d0/872adae5f5a62e33f514aeb2458f8caaa3b73f08459232a71acfdff348e5/keyrings.alt-3.2.0-py2.py3-none-any.whl
# Collecting tzlocal==2.0.0
#   Downloading https://files.pythonhosted.org/packages/ef/99/53bd1ac9349262f59c1c421d8fcc2559ae8a5eeffed9202684756b648d33/tzlocal-2.0.0-py2.py3-none-any.whl
# Collecting pytz>=2019.3
#   Downloading https://files.pythonhosted.org/packages/4f/a4/879454d49688e2fad93e59d7d4efda580b783c745fd2ec2a3adf87b0808d/pytz-2020.1-py2.py3-none-any.whl (510kB)
#      |████████████████████████████████| 512kB 29.8MB/s
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.6/dist-packages (from pyicloud) (2.23.0)
# Requirement already satisfied: certifi>=2019.11.28 in /usr/local/lib/python3.6/dist-packages (from pyicloud) (2020.4.5.2)
# Collecting secretstorage; sys_platform == "linux2" or sys_platform == "linux"
#   Downloading https://files.pythonhosted.org/packages/c3/50/8a02cad020e949e6d7105f5f4530d41e3febcaa5b73f8f2148aacb3aeba5/SecretStorage-3.1.2-py3-none-any.whl
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->pyicloud) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->pyicloud) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->pyicloud) (2.9)
# Collecting cryptography
#   Downloading https://files.pythonhosted.org/packages/3c/04/686efee2dcdd25aecf357992e7d9362f443eb182ecd623f882bc9f7a6bba/cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7MB)
#      |████████████████████████████████| 2.7MB 50.6MB/s
# Collecting jeepney>=0.4.2
#   Downloading https://files.pythonhosted.org/packages/79/31/2e8d42727595faf224c6dbb748c32b192e212f25495fe841fb7ce8e168b8/jeepney-0.4.3-py3-none-any.whl
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/dist-packages (from cryptography->secretstorage; sys_platform == "linux2" or sys_platform == "linux"->keyring<=9.3.1,>=8.0->pyicloud) (1.14.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi!=1.11.3,>=1.8->cryptography->secretstorage; sys_platform == "linux2" or sys_platform == "linux"->keyring<=9.3.1,>=8.0->pyicloud) (2.20)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-cp36-none-any.whl size=491057 sha256=fb1ed38de10cd6e9785b2e22712e8d94a4b0f4f7990bfa465f50079a8e22d896
#   Stored in directory: /root/.cache/pip/wheels/8b/99/a0/81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e
# Successfully built future
# ERROR: google-colab 1.0.0 has requirement six~=1.12.0, but you'll have six 1.15.0 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: six, cryptography, jeepney, secretstorage, keyring, click, future, keyrings.alt, pytz, tzlocal, pyicloud
#   Found existing installation: six 1.12.0
#     Uninstalling six-1.12.0:
#       Successfully uninstalled six-1.12.0
#   Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
#   Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
#   Found existing installation: pytz 2018.9
#     Uninstalling pytz-2018.9:
#       Successfully uninstalled pytz-2018.9
#   Found existing installation: tzlocal 1.5.1
#     Uninstalling tzlocal-1.5.1:
#       Successfully uninstalled tzlocal-1.5.1
# Successfully installed click-7.1.1 cryptography-2.9.2 future-0.18.2 jeepney-0.4.3 keyring-9.3.1 keyrings.alt-3.2.0 pyicloud-0.9.7 pytz-2020.1 secretstorage-3.1.2 six-1.15.0 tzlocal-2.0.0

# %%
from pyicloud import PyiCloudService

# %%
import getpass

# %%
password = getpass.getpass()
# Out:
# ··········

# %%
api = PyiCloudService('vojtech.kase@gmail.com', password)

# %%
print(api.devices)
# Out:
# {'VJROhchHI8e7BeB7BpLJU8x7P2d/kTnjd/Z+oubwYtx2Yldax0m30w==': <AppleDevice(MacBook: Vojtěch’s MacBook)>, 'of1mMyqaIOTtdJX84uwBDBIH75CWW//N6+673VbF5my4eT/rEmUyjQ==': <AppleDevice(MacBook Air 13": d37560)>, 'nmhhbE4nVfMXNUKCI1lyekbONLYYEdztUgb0AwFrOxT/Zw/gVbrIHOHYVNSUzmWV': <AppleDevice(iPad mini 4: Vojtěch - iPad)>, 'a35Ov5RUXnD8y1c/n3NqnO7jCcVoMG92VBlcAS0+DhYH/Fah1T2H9uHYVNSUzmWV': <AppleDevice(iPhone 5s: Vojtěch’s iPhone)>, 'Vmqtrete1yvwQB+VNAyz4N4c8xwfhjok0FPwLv+Tl6ZJC96FSPDmwOHYVNSUzmWV': <AppleDevice(iPad mini: Vojtěch - iPad)>, 'fQfzaZPlaybwYYRpAlydMfQiwNhwPE2D+dGfrKz/VJnZuEQIMoZjS+HYVNSUzmWV': <AppleDevice(iPhone 7: Vojtěch’s iPhone)>, 'Q6/+9Z1YlZSPUM62AjvU+oQU2YuMTpCKmqx7jS19T1y09LwITvWk5g==': <AppleDevice(MacBook: vojtech - MacBook)>}

# %%
api.devices
# Out:
# {'VJROhchHI8e7BeB7BpLJU8x7P2d/kTnjd/Z+oubwYtx2Yldax0m30w==': <AppleDevice(MacBook: Vojtěch’s MacBook)>, 'of1mMyqaIOTtdJX84uwBDBIH75CWW//N6+673VbF5my4eT/rEmUyjQ==': <AppleDevice(MacBook Air 13": d37560)>, 'nmhhbE4nVfMXNUKCI1lyekbONLYYEdztUgb0AwFrOxT/Zw/gVbrIHOHYVNSUzmWV': <AppleDevice(iPad mini 4: Vojtěch - iPad)>, 'a35Ov5RUXnD8y1c/n3NqnO7jCcVoMG92VBlcAS0+DhYH/Fah1T2H9uHYVNSUzmWV': <AppleDevice(iPhone 5s: Vojtěch’s iPhone)>, 'Vmqtrete1yvwQB+VNAyz4N4c8xwfhjok0FPwLv+Tl6ZJC96FSPDmwOHYVNSUzmWV': <AppleDevice(iPad mini: Vojtěch - iPad)>, 'fQfzaZPlaybwYYRpAlydMfQiwNhwPE2D+dGfrKz/VJnZuEQIMoZjS+HYVNSUzmWV': <AppleDevice(iPhone 7: Vojtěch’s iPhone)>, 'Q6/+9Z1YlZSPUM62AjvU+oQU2YuMTpCKmqx7jS19T1y09LwITvWk5g==': <AppleDevice(MacBook: vojtech - MacBook)>}

# %%
devices[5]
# Out:
# <AppleDevice(iPhone 7: Vojtěch’s iPhone)>

# %%
if api.requires_2sa:
    import click
    print("Two-step authentication required. Your trusted devices are:")


    devices = api.devices
    for i, device in enumerate(devices):
        print("  %s: %s" % (i, device.get('deviceName',"SMS to %s" % device.get('phoneNumber'))))

    device = click.prompt('Which device would you like to use?', default=0)
    device = devices[device]
    if not api.send_verification_code(device):
        print("Failed to send verification code") 
        sys.exit(1)

    code = click.prompt('Please enter validation code')
    if not api.validate_verification_code(device, code):
        print("Failed to verify verification code")
        sys.exit(1)
# Out:
# Two-step authentication required. Your trusted devices are:
#   0: SMS to None
#   1: SMS to None
#   2: SMS to None
#   3: SMS to None
#   4: SMS to None
#   5: SMS to None
#   6: SMS to None
# Which device would you like to use? [0]: fQfzaZPlaybwYYRpAlydMfQiwNhwPE2D+dGfrKz/VJnZuEQIMoZjS+HYVNSUzmWV
# Error: fQfzaZPlaybwYYRpAlydMfQiwNhwPE2D+dGfrKz/VJnZuEQIMoZjS+HYVNSUzmWV is not a valid integer
# Which device would you like to use? [0]: 6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-5fb306c3cfae> in <module>()
#      10     device = click.prompt('Which device would you like to use?', default=0)
#      11     device = devices[device]
# ---> 12     if not api.send_verification_code(device):
#      13         print("Failed to send verification code")
#      14         sys.exit(1)
#
# /usr/local/lib/python3.6/dist-packages/pyicloud/base.py in send_verification_code(self, device)
#     278     def send_verification_code(self, device):
#     279         """Requests that a verification code is sent to the given device."""
# --> 280         data = json.dumps(device)
#     281         request = self.session.post(
#     282             "%s/sendVerificationCode" % self.SETUP_ENDPOINT,
#
# /usr/lib/python3.6/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     229         cls is None and indent is None and separators is None and
#     230         default is None and not sort_keys and not kw):
# --> 231         return _default_encoder.encode(obj)
#     232     if cls is None:
#     233         cls = JSONEncoder
#
# /usr/lib/python3.6/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /usr/lib/python3.6/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/lib/python3.6/json/encoder.py in default(self, o)
#     178         """
#     179         raise TypeError("Object of type '%s' is not JSON serializable" %
# --> 180                         o.__class__.__name__)
#     181
#     182     def encode(self, o):
#
# TypeError: Object of type 'AppleDevice' is not JSON serializable

# %%
api.send_verification_code({"deviceID" : 'fQfzaZPlaybwYYRpAlydMfQiwNhwPE2D+dGfrKz/VJnZuEQIMoZjS+HYVNSUzmWV'})
# Out:
# ---------------------------------------------------------------------------
# PyiCloudAPIResponseException              Traceback (most recent call last)
# <ipython-input-61-ac751d506a88> in <module>()
# ----> 1 api.send_verification_code({"deviceID" : 'fQfzaZPlaybwYYRpAlydMfQiwNhwPE2D+dGfrKz/VJnZuEQIMoZjS+HYVNSUzmWV'})
#
# /usr/local/lib/python3.6/dist-packages/pyicloud/base.py in send_verification_code(self, device)
#     282             "%s/sendVerificationCode" % self.SETUP_ENDPOINT,
#     283             params=self.params,
# --> 284             data=data,
#     285         )
#     286         return request.json().get("success", False)
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     576         """
#     577
# --> 578         return self.request('POST', url, data=data, json=json, **kwargs)
#     579
#     580     def put(self, url, data=None, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/pyicloud/base.py in request(self, method, url, **kwargs)
#     111
#     112         if reason:
# --> 113             self._raise_error(code, reason)
#     114
#     115         return response
#
# /usr/local/lib/python3.6/dist-packages/pyicloud/base.py in _raise_error(self, code, reason)
#     138         api_error = PyiCloudAPIResponseException(reason, code)
#     139         LOGGER.error(api_error)
# --> 140         raise api_error
#     141
#     142
#
# PyiCloudAPIResponseException: Invalid or missing deviceId field

# %%
for id, device in api.devices.items():
        print 'Name: %s -- ID: %s' % (
            str(device),
            str(id),
        )

# %%
# Out:
# <AppleDevice(MacBook: Vojtěch’s MacBook)>

# %%
612957

# %%
api.files.dir()
# Out:
# ---------------------------------------------------------------------------
# PyiCloudAPIResponseException              Traceback (most recent call last)
# <ipython-input-44-cc64748652b0> in <module>()
# ----> 1 api.files.dir()
#
# /usr/local/lib/python3.6/dist-packages/pyicloud/services/ubiquity.py in __getattr__(self, attr)
#      41
#      42     def __getattr__(self, attr):
# ---> 43         return getattr(self.root, attr)
#      44
#      45     def __getitem__(self, key):
#
# /usr/local/lib/python3.6/dist-packages/pyicloud/services/ubiquity.py in root(self)
#      18         """Gets the root node."""
#      19         if not self._root:
# ---> 20             self._root = self.get_node(0)
#      21         return self._root
#      22
#
# /usr/local/lib/python3.6/dist-packages/pyicloud/services/ubiquity.py in get_node(self, node_id)
#      27     def get_node(self, node_id):
#      28         """Returns a node."""
# ---> 29         request = self.session.get(self.get_node_url(node_id))
#      30         return UbiquityNode(self, request.json())
#      31
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     541
#     542         kwargs.setdefault('allow_redirects', True)
# --> 543         return self.request('GET', url, **kwargs)
#     544
#     545     def options(self, url, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/pyicloud/base.py in request(self, method, url, **kwargs)
#      85                 kwargs["retried"] = True
#      86                 return self.request(method, url, **kwargs)
# ---> 87             self._raise_error(response.status_code, response.reason)
#      88
#      89         if content_type not in json_mimetypes:
#
# /usr/local/lib/python3.6/dist-packages/pyicloud/base.py in _raise_error(self, code, reason)
#     138         api_error = PyiCloudAPIResponseException(reason, code)
#     139         LOGGER.error(api_error)
# --> 140         raise api_error
#     141
#     142
#
# PyiCloudAPIResponseException: Unauthorized (401)

# %%
devices = [{'areaCode': '+45',
  'deviceId': '0',
  'deviceType': 'SMS',
  'phoneNumber': '26250460'}]

# %%
import click
for i, device in enumerate(devices):
  print("  %s: %s" % (i, device.get('deviceName',"SMS to %s" % device.get('phoneNumber'))))
# Out:
#   0: SMS to 26250460

# %%
import sys

# %%
if not api.send_verification_code(device):
  print("Failed to send verification code")
  sys.exit(1)
# Out:
# Failed to send verification code
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
api.devices
# Out:
# {'VJROhchHI8e7BeB7BpLJU8x7P2d/kTnjd/Z+oubwYtx2Yldax0m30w==': <AppleDevice(MacBook: Vojtěch’s MacBook)>, 'of1mMyqaIOTtdJX84uwBDBIH75CWW//N6+673VbF5my4eT/rEmUyjQ==': <AppleDevice(MacBook Air 13": d37560)>, 'nmhhbE4nVfMXNUKCI1lyekbONLYYEdztUgb0AwFrOxT/Zw/gVbrIHOHYVNSUzmWV': <AppleDevice(iPad mini 4: Vojtěch - iPad)>, 'a35Ov5RUXnD8y1c/n3NqnO7jCcVoMG92VBlcAS0+DhYH/Fah1T2H9uHYVNSUzmWV': <AppleDevice(iPhone 5s: Vojtěch’s iPhone)>, 'Vmqtrete1yvwQB+VNAyz4N4c8xwfhjok0FPwLv+Tl6ZJC96FSPDmwOHYVNSUzmWV': <AppleDevice(iPad mini: Vojtěch - iPad)>, 'fQfzaZPlaybwYYRpAlydMfQiwNhwPE2D+dGfrKz/VJnZuEQIMoZjS+HYVNSUzmWV': <AppleDevice(iPhone 7: Vojtěch’s iPhone)>, 'Q6/+9Z1YlZSPUM62AjvU+oQU2YuMTpCKmqx7jS19T1y09LwITvWk5g==': <AppleDevice(MacBook: vojtech - MacBook)>}

# %%
api.validate_verification_code("of1mMyqaIOTtdJX84uwBDBIH75CWW//N6+673VbF5my4eT/rEmUyjQ==", "612957")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-75b2f4d14d91> in <module>()
# ----> 1 api.validate_verification_code("of1mMyqaIOTtdJX84uwBDBIH75CWW//N6+673VbF5my4eT/rEmUyjQ==", "612957")
#
# /usr/local/lib/python3.6/dist-packages/pyicloud/base.py in validate_verification_code(self, device, code)
#     288     def validate_verification_code(self, device, code):
#     289         """Verifies a verification code received on a trusted device."""
# --> 290         device.update({"verificationCode": code, "trustBrowser": True})
#     291         data = json.dumps(device)
#     292
#
# AttributeError: 'str' object has no attribute 'update'

# %%
code = click.prompt('Please enter validation code')
api.validate_verification_code("3", code)
# Out:
# Please enter validation code: 187474
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-92387bee07ca> in <module>()
#       1 code = click.prompt('Please enter validation code')
# ----> 2 api.validate_verification_code("3", code)
#
# /usr/local/lib/python3.6/dist-packages/pyicloud/base.py in validate_verification_code(self, device, code)
#     288     def validate_verification_code(self, device, code):
#     289         """Verifies a verification code received on a trusted device."""
# --> 290         device.update({"verificationCode": code, "trustBrowser": True})
#     291         data = json.dumps(device)
#     292
#
# AttributeError: 'str' object has no attribute 'update'

# %%
if api.requires_2sa:
    import click
    print "Two-step authentication required. Your trusted devices are:"

    devices = api.trusted_devices
    for i, device in enumerate(devices):
        print "  %s: %s" % (i, device.get('deviceName',
            "SMS to %s" % device.get('phoneNumber')))

    device = click.prompt('Which device would you like to use?', default=0)
    device = devices[device]
    if not api.send_verification_code(device):
        print "Failed to send verification code"
        sys.exit(1)

    code = click.prompt('Please enter validation code')
    if not api.validate_verification_code(device, code):
        print "Failed to verify verification code"
        sys.exit(1)
